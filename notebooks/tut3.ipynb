# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
res= []
for i in range(7):
    for j in range(7):
        sum =  i + j
        if sum == 7:
            res.append((i, j))
res
# Out:
# [(1, 6), (2, 5), (3, 4), (4, 3), (5, 2), (6, 1)]

# %%
from scipy import stats

# %%
from scipy import stats

mu = 30       # mean
sigma = 1.8    # standard deviation

X = stats.norm(loc=mu, scale=sigma)

p = X.cdf(33) - X.cdf(28)
p
# Out:
# np.float64(0.8189493848246799)

# %%
from numpy.linalg import matrix_rank
matrix_rank([[1, 2, 3], [4, 5, 6], [7, 8, 9]])
# Out:
# np.int64(2)
