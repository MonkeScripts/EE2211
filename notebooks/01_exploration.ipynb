# %% [markdown]
# # Data Exploration
# Initial exploration and profiling of the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='darkgrid')
# %matplotlib inline

# %%
# Load data
# df = pd.read_csv('../data/raw/your_file.csv')
# df.head()
